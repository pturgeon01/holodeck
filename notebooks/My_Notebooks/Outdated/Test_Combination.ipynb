# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

from utils import TwoDimParVar

nints = 10
rangespsi0 = np.linspace(-3.5,-1.3,nints)
rangeslogm0 = np.linspace(10.5, 12.7, nints)
rangesmu = np.linspace(7.5,9.7, nints)
rangeseps = np.linspace(0, 1, nints)
rangestau = np.linspace(0.1, 11.0, nints)
rangesgamma = np.linspace(-1.5,0, nints)
psi0 = ('psi0',rangespsi0)
m0 = ('m0',rangeslogm0)
mass_norm = ('mass_norm',rangesmu)
scatter = ('scatter', rangeseps)
tau = ('tau', rangestau)
gamma_inner = ('gamma_inner',rangesgamma)

# %%
ranges = dict([psi0, m0])

t = TwoDimParVar(ranges,bound_type='hc',shape=5, load = False)

t.getStrain()
print('Done')
# Out:
# GW single source strain calculation is 0.0% done.
# 16:02:47 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:47 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:47 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:47 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 9.54e-05, 2.86e-02, 2.11e-01, 7.27e-01) [sam.py:static_binary_density]
# 16:02:47 INFO : Scatter added after 0.179678 sec [sam.py:static_binary_density]
# 16:02:47 INFO : 	dens aft: (2.63e-25, 6.74e-20, 6.17e-09, 3.95e-04, 5.90e-02, 2.45e-01, 6.97e-01) [sam.py:static_binary_density]
# 16:02:47 INFO : 	mass: 7.41e-02 ==> 3.23e-01 || change = 3.3618e+00 [sam.py:static_binary_density]
# 16:02:47 ERROR : Warning, significant change in number-mass!  mass: 7.41e-02 ==> 3.23e-01 || change = 3.3618e+00 [sam.py:static_binary_density]
# 16:02:47 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:47 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:47 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:47 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:47 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 1.11e-04, 3.27e-02, 2.41e-01, 8.47e-01) [sam.py:static_binary_density]
# 16:02:47 INFO : Scatter added after 0.159038 sec [sam.py:static_binary_density]
# 16:02:47 INFO : 	dens aft: (6.26e-25, 1.38e-19, 8.88e-09, 1.51e-03, 1.17e-01, 2.82e-01, 8.12e-01) [sam.py:static_binary_density]
# 16:02:47 INFO : 	mass: 9.46e-02 ==> 4.42e-01 || change = 3.6692e+00 [sam.py:static_binary_density]
# 16:02:47 ERROR : Warning, significant change in number-mass!  mass: 9.46e-02 ==> 4.42e-01 || change = 3.6692e+00 [sam.py:static_binary_density]
# 16:02:47 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:47 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:47 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:47 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:47 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 1.36e-04, 4.75e-02, 4.44e-01, 9.86e-01) [sam.py:static_binary_density]
# 16:02:47 INFO : Scatter added after 0.129529 sec [sam.py:static_binary_density]
# 16:02:47 INFO : 	dens aft: (1.17e-24, 2.21e-19, 1.69e-08, 3.31e-03, 1.39e-01, 3.24e-01, 9.45e-01) [sam.py:static_binary_density]
# 16:02:47 INFO : 	mass: 1.22e-01 ==> 6.30e-01 || change = 4.1582e+00 [sam.py:static_binary_density]
# 16:02:47 ERROR : Warning, significant change in number-mass!  mass: 1.22e-01 ==> 6.30e-01 || change = 4.1582e+00 [sam.py:static_binary_density]
# 16:02:47 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:47 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:47 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:47 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:47 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 1.56e-04, 6.42e-02, 6.11e-01, 1.15e+00) [sam.py:static_binary_density]
# 16:02:47 INFO : Scatter added after 0.14053 sec [sam.py:static_binary_density]
# 16:02:47 INFO : 	dens aft: (1.22e-19, 2.34e-15, 2.79e-08, 5.45e-03, 1.65e-01, 4.36e-01, 1.10e+00) [sam.py:static_binary_density]
# 16:02:47 INFO : 	mass: 1.55e-01 ==> 8.53e-01 || change = 4.4908e+00 [sam.py:static_binary_density]
# 16:02:47 ERROR : Warning, significant change in number-mass!  mass: 1.55e-01 ==> 8.53e-01 || change = 4.4908e+00 [sam.py:static_binary_density]
# 16:02:47 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:47 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:47 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:47 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:47 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 1.78e-04, 8.11e-02, 7.48e-01, 1.34e+00) [sam.py:static_binary_density]
# 16:02:48 INFO : Scatter added after 0.090294 sec [sam.py:static_binary_density]
# 16:02:48 INFO : 	dens aft: (3.37e-15, 5.01e-11, 3.98e-08, 7.25e-03, 2.26e-01, 5.45e-01, 1.28e+00) [sam.py:static_binary_density]
# 16:02:48 INFO : 	mass: 1.93e-01 ==> 1.10e+00 || change = 4.7184e+00 [sam.py:static_binary_density]
# 16:02:48 ERROR : Warning, significant change in number-mass!  mass: 1.93e-01 ==> 1.10e+00 || change = 4.7184e+00 [sam.py:static_binary_density]
# 16:02:48 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:48 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:48 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:48 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:48 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 2.12e-04, 1.00e-01, 8.97e-01, 1.56e+00) [sam.py:static_binary_density]
# 16:02:48 INFO : Scatter added after 0.157328 sec [sam.py:static_binary_density]
# 16:02:48 INFO : 	dens aft: (1.30e-12, 1.27e-08, 1.41e-07, 9.43e-03, 2.91e-01, 6.50e-01, 1.49e+00) [sam.py:static_binary_density]
# 16:02:48 INFO : 	mass: 2.35e-01 ==> 1.37e+00 || change = 4.8410e+00 [sam.py:static_binary_density]
# 16:02:48 ERROR : Warning, significant change in number-mass!  mass: 2.35e-01 ==> 1.37e+00 || change = 4.8410e+00 [sam.py:static_binary_density]
# 16:02:48 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:48 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:48 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:48 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:48 INFO : 	dens bef: (0.00e+00, 0.00e+00, 3.48e-185, 7.95e-04, 1.29e-01, 1.06e+00, 1.81e+00) [sam.py:static_binary_density]
# 16:02:48 INFO : Scatter added after 0.115104 sec [sam.py:static_binary_density]
# 16:02:48 INFO : 	dens aft: (4.43e-11, 1.49e-07, 3.03e-06, 1.11e-02, 3.57e-01, 8.16e-01, 1.74e+00) [sam.py:static_binary_density]
# 16:02:48 INFO : 	mass: 2.83e-01 ==> 1.67e+00 || change = 4.8949e+00 [sam.py:static_binary_density]
# 16:02:48 ERROR : Warning, significant change in number-mass!  mass: 2.83e-01 ==> 1.67e+00 || change = 4.8949e+00 [sam.py:static_binary_density]
# 16:02:48 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:48 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:48 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:48 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:48 INFO : 	dens bef: (4.56e-203, 1.98e-197, 6.11e-109, 1.76e-03, 2.04e-01, 1.28e+00, 2.11e+00) [sam.py:static_binary_density]
# 16:02:48 INFO : Scatter added after 0.130257 sec [sam.py:static_binary_density]
# 16:02:48 INFO : 	dens aft: (3.76e-10, 1.08e-06, 3.22e-05, 2.16e-02, 4.64e-01, 1.07e+00, 2.02e+00) [sam.py:static_binary_density]
# 16:02:48 INFO : 	mass: 3.44e-01 ==> 2.03e+00 || change = 4.9079e+00 [sam.py:static_binary_density]
# 16:02:48 ERROR : Warning, significant change in number-mass!  mass: 3.44e-01 ==> 2.03e+00 || change = 4.9079e+00 [sam.py:static_binary_density]
# 16:02:48 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:48 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:48 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:48 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:48 INFO : 	dens bef: (2.66e-117, 9.76e-112, 1.86e-65, 2.77e-03, 2.90e-01, 2.25e+00, 3.44e+00) [sam.py:static_binary_density]
# 16:02:48 INFO : Scatter added after 0.075196 sec [sam.py:static_binary_density]
# 16:02:48 INFO : 	dens aft: (1.45e-09, 2.11e-05, 5.01e-04, 4.15e-02, 7.15e-01, 1.52e+00, 2.53e+00) [sam.py:static_binary_density]
# 16:02:48 INFO : 	mass: 4.57e-01 ==> 2.83e+00 || change = 5.2069e+00 [sam.py:static_binary_density]
# 16:02:48 ERROR : Warning, significant change in number-mass!  mass: 4.57e-01 ==> 2.83e+00 || change = 5.2069e+00 [sam.py:static_binary_density]
# 16:02:48 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:48 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:48 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:48 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:48 INFO : 	dens bef: (2.15e-68, 4.12e-63, 1.24e-40, 3.23e-03, 5.59e-01, 2.63e+00, 1.28e+01) [sam.py:static_binary_density]
# 16:02:48 INFO : Scatter added after 0.124275 sec [sam.py:static_binary_density]
# 16:02:48 INFO : 	dens aft: (3.55e-09, 2.98e-05, 1.71e-03, 9.05e-02, 1.35e+00, 2.38e+00, 9.40e+00) [sam.py:static_binary_density]
# 16:02:48 INFO : 	mass: 6.78e-01 ==> 4.81e+00 || change = 6.0904e+00 [sam.py:static_binary_density]
# 16:02:48 ERROR : Warning, significant change in number-mass!  mass: 6.78e-01 ==> 4.81e+00 || change = 6.0904e+00 [sam.py:static_binary_density]
# 16:02:48 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# GW single source strain calculation is 10.0% done.
# 16:02:48 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:48 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:49 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:49 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 1.67e-04, 5.02e-02, 3.70e-01, 1.28e+00) [sam.py:static_binary_density]
# 16:02:49 INFO : Scatter added after 0.139265 sec [sam.py:static_binary_density]
# 16:02:49 INFO : 	dens aft: (4.62e-25, 1.18e-19, 1.08e-08, 6.94e-04, 1.04e-01, 4.30e-01, 1.22e+00) [sam.py:static_binary_density]
# 16:02:49 INFO : 	mass: 1.30e-01 ==> 5.67e-01 || change = 3.3618e+00 [sam.py:static_binary_density]
# 16:02:49 ERROR : Warning, significant change in number-mass!  mass: 1.30e-01 ==> 5.67e-01 || change = 3.3618e+00 [sam.py:static_binary_density]
# 16:02:49 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:49 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:49 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:49 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:49 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 1.95e-04, 5.75e-02, 4.24e-01, 1.49e+00) [sam.py:static_binary_density]
# 16:02:49 INFO : Scatter added after 0.119957 sec [sam.py:static_binary_density]
# 16:02:49 INFO : 	dens aft: (1.10e-24, 2.42e-19, 1.56e-08, 2.64e-03, 2.06e-01, 4.95e-01, 1.43e+00) [sam.py:static_binary_density]
# 16:02:49 INFO : 	mass: 1.66e-01 ==> 7.76e-01 || change = 3.6692e+00 [sam.py:static_binary_density]
# 16:02:49 ERROR : Warning, significant change in number-mass!  mass: 1.66e-01 ==> 7.76e-01 || change = 3.6692e+00 [sam.py:static_binary_density]
# 16:02:49 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:49 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:49 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:49 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:49 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 2.39e-04, 8.34e-02, 7.79e-01, 1.73e+00) [sam.py:static_binary_density]
# 16:02:49 INFO : Scatter added after 0.132187 sec [sam.py:static_binary_density]
# 16:02:49 INFO : 	dens aft: (2.05e-24, 3.88e-19, 2.96e-08, 5.80e-03, 2.44e-01, 5.69e-01, 1.66e+00) [sam.py:static_binary_density]
# 16:02:49 INFO : 	mass: 2.15e-01 ==> 1.11e+00 || change = 4.1582e+00 [sam.py:static_binary_density]
# 16:02:49 ERROR : Warning, significant change in number-mass!  mass: 2.15e-01 ==> 1.11e+00 || change = 4.1582e+00 [sam.py:static_binary_density]
# 16:02:49 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:49 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:49 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:49 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:49 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 2.73e-04, 1.13e-01, 1.07e+00, 2.01e+00) [sam.py:static_binary_density]
# 16:02:49 INFO : Scatter added after 0.124967 sec [sam.py:static_binary_density]
# 16:02:49 INFO : 	dens aft: (2.13e-19, 4.11e-15, 4.90e-08, 9.56e-03, 2.90e-01, 7.66e-01, 1.93e+00) [sam.py:static_binary_density]
# 16:02:49 INFO : 	mass: 2.73e-01 ==> 1.50e+00 || change = 4.4908e+00 [sam.py:static_binary_density]
# 16:02:49 ERROR : Warning, significant change in number-mass!  mass: 2.73e-01 ==> 1.50e+00 || change = 4.4908e+00 [sam.py:static_binary_density]
# 16:02:49 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:49 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:49 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:49 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:49 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 3.13e-04, 1.42e-01, 1.31e+00, 2.35e+00) [sam.py:static_binary_density]
# 16:02:49 INFO : Scatter added after 0.095827 sec [sam.py:static_binary_density]
# 16:02:49 INFO : 	dens aft: (5.92e-15, 8.80e-11, 6.98e-08, 1.27e-02, 3.96e-01, 9.57e-01, 2.25e+00) [sam.py:static_binary_density]
# 16:02:49 INFO : 	mass: 3.38e-01 ==> 1.94e+00 || change = 4.7184e+00 [sam.py:static_binary_density]
# 16:02:49 ERROR : Warning, significant change in number-mass!  mass: 3.38e-01 ==> 1.94e+00 || change = 4.7184e+00 [sam.py:static_binary_density]
# 16:02:49 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:49 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:49 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:49 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:49 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 3.71e-04, 1.76e-01, 1.57e+00, 2.73e+00) [sam.py:static_binary_density]
# 16:02:50 INFO : Scatter added after 0.130681 sec [sam.py:static_binary_density]
# 16:02:50 INFO : 	dens aft: (2.29e-12, 2.23e-08, 2.47e-07, 1.66e-02, 5.10e-01, 1.14e+00, 2.62e+00) [sam.py:static_binary_density]
# 16:02:50 INFO : 	mass: 4.12e-01 ==> 2.41e+00 || change = 4.8410e+00 [sam.py:static_binary_density]
# 16:02:50 ERROR : Warning, significant change in number-mass!  mass: 4.12e-01 ==> 2.41e+00 || change = 4.8410e+00 [sam.py:static_binary_density]
# 16:02:50 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:50 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:50 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:50 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:50 INFO : 	dens bef: (0.00e+00, 0.00e+00, 6.12e-185, 1.40e-03, 2.27e-01, 1.86e+00, 3.18e+00) [sam.py:static_binary_density]
# 16:02:50 INFO : Scatter added after 0.111573 sec [sam.py:static_binary_density]
# 16:02:50 INFO : 	dens aft: (7.77e-11, 2.61e-07, 5.33e-06, 1.94e-02, 6.27e-01, 1.43e+00, 3.05e+00) [sam.py:static_binary_density]
# 16:02:50 INFO : 	mass: 4.96e-01 ==> 2.93e+00 || change = 4.8949e+00 [sam.py:static_binary_density]
# 16:02:50 ERROR : Warning, significant change in number-mass!  mass: 4.96e-01 ==> 2.93e+00 || change = 4.8949e+00 [sam.py:static_binary_density]
# 16:02:50 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:50 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:50 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:50 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:50 INFO : 	dens bef: (8.00e-203, 3.48e-197, 1.07e-108, 3.09e-03, 3.58e-01, 2.24e+00, 3.70e+00) [sam.py:static_binary_density]
# 16:02:50 INFO : Scatter added after 0.153599 sec [sam.py:static_binary_density]
# 16:02:50 INFO : 	dens aft: (6.59e-10, 1.90e-06, 5.64e-05, 3.80e-02, 8.15e-01, 1.88e+00, 3.55e+00) [sam.py:static_binary_density]
# 16:02:50 INFO : 	mass: 6.04e-01 ==> 3.57e+00 || change = 4.9079e+00 [sam.py:static_binary_density]
# 16:02:50 ERROR : Warning, significant change in number-mass!  mass: 6.04e-01 ==> 3.57e+00 || change = 4.9079e+00 [sam.py:static_binary_density]
# 16:02:50 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:50 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:50 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:50 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:50 INFO : 	dens bef: (4.67e-117, 1.71e-111, 3.27e-65, 4.87e-03, 5.09e-01, 3.95e+00, 6.03e+00) [sam.py:static_binary_density]
# 16:02:50 INFO : Scatter added after 0.140692 sec [sam.py:static_binary_density]
# 16:02:50 INFO : 	dens aft: (2.54e-09, 3.70e-05, 8.80e-04, 7.29e-02, 1.25e+00, 2.68e+00, 4.45e+00) [sam.py:static_binary_density]
# 16:02:50 INFO : 	mass: 8.02e-01 ==> 4.98e+00 || change = 5.2069e+00 [sam.py:static_binary_density]
# 16:02:50 ERROR : Warning, significant change in number-mass!  mass: 8.02e-01 ==> 4.98e+00 || change = 5.2069e+00 [sam.py:static_binary_density]
# 16:02:50 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:50 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:50 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:50 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:50 INFO : 	dens bef: (3.77e-68, 7.24e-63, 2.18e-40, 5.67e-03, 9.82e-01, 4.62e+00, 2.25e+01) [sam.py:static_binary_density]
# 16:02:50 INFO : Scatter added after 0.155566 sec [sam.py:static_binary_density]
# 16:02:50 INFO : 	dens aft: (6.24e-09, 5.24e-05, 2.99e-03, 1.59e-01, 2.38e+00, 4.19e+00, 1.65e+01) [sam.py:static_binary_density]
# 16:02:50 INFO : 	mass: 1.19e+00 ==> 8.45e+00 || change = 6.0904e+00 [sam.py:static_binary_density]
# 16:02:50 ERROR : Warning, significant change in number-mass!  mass: 1.19e+00 ==> 8.45e+00 || change = 6.0904e+00 [sam.py:static_binary_density]
# 16:02:50 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# GW single source strain calculation is 20.0% done.
# 16:02:50 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:50 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:50 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:50 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 2.94e-04, 8.81e-02, 6.50e-01, 2.24e+00) [sam.py:static_binary_density]
# 16:02:50 INFO : Scatter added after 0.104561 sec [sam.py:static_binary_density]
# 16:02:50 INFO : 	dens aft: (8.11e-25, 2.08e-19, 1.90e-08, 1.22e-03, 1.82e-01, 7.55e-01, 2.15e+00) [sam.py:static_binary_density]
# 16:02:50 INFO : 	mass: 2.28e-01 ==> 9.96e-01 || change = 3.3618e+00 [sam.py:static_binary_density]
# 16:02:50 ERROR : Warning, significant change in number-mass!  mass: 2.28e-01 ==> 9.96e-01 || change = 3.3618e+00 [sam.py:static_binary_density]
# 16:02:50 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:50 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:50 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:50 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:50 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 3.42e-04, 1.01e-01, 7.44e-01, 2.61e+00) [sam.py:static_binary_density]
# 16:02:51 INFO : Scatter added after 0.144305 sec [sam.py:static_binary_density]
# 16:02:51 INFO : 	dens aft: (1.93e-24, 4.24e-19, 2.74e-08, 4.64e-03, 3.61e-01, 8.69e-01, 2.50e+00) [sam.py:static_binary_density]
# 16:02:51 INFO : 	mass: 2.92e-01 ==> 1.36e+00 || change = 3.6692e+00 [sam.py:static_binary_density]
# 16:02:51 ERROR : Warning, significant change in number-mass!  mass: 2.92e-01 ==> 1.36e+00 || change = 3.6692e+00 [sam.py:static_binary_density]
# 16:02:51 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:51 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:51 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:51 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:51 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 4.19e-04, 1.46e-01, 1.37e+00, 3.04e+00) [sam.py:static_binary_density]
# 16:02:51 INFO : Scatter added after 0.201602 sec [sam.py:static_binary_density]
# 16:02:51 INFO : 	dens aft: (3.61e-24, 6.81e-19, 5.19e-08, 1.02e-02, 4.28e-01, 9.99e-01, 2.91e+00) [sam.py:static_binary_density]
# 16:02:51 INFO : 	mass: 3.77e-01 ==> 1.94e+00 || change = 4.1582e+00 [sam.py:static_binary_density]
# 16:02:51 ERROR : Warning, significant change in number-mass!  mass: 3.77e-01 ==> 1.94e+00 || change = 4.1582e+00 [sam.py:static_binary_density]
# 16:02:51 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:51 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:51 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:51 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:51 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 4.80e-04, 1.98e-01, 1.88e+00, 3.54e+00) [sam.py:static_binary_density]
# 16:02:51 INFO : Scatter added after 0.131456 sec [sam.py:static_binary_density]
# 16:02:51 INFO : 	dens aft: (3.75e-19, 7.21e-15, 8.61e-08, 1.68e-02, 5.09e-01, 1.35e+00, 3.39e+00) [sam.py:static_binary_density]
# 16:02:51 INFO : 	mass: 4.79e-01 ==> 2.63e+00 || change = 4.4908e+00 [sam.py:static_binary_density]
# 16:02:51 ERROR : Warning, significant change in number-mass!  mass: 4.79e-01 ==> 2.63e+00 || change = 4.4908e+00 [sam.py:static_binary_density]
# 16:02:51 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:51 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:51 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:51 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:51 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 5.49e-04, 2.50e-01, 2.31e+00, 4.12e+00) [sam.py:static_binary_density]
# 16:02:51 INFO : Scatter added after 0.172256 sec [sam.py:static_binary_density]
# 16:02:51 INFO : 	dens aft: (1.04e-14, 1.54e-10, 1.23e-07, 2.24e-02, 6.95e-01, 1.68e+00, 3.95e+00) [sam.py:static_binary_density]
# 16:02:51 INFO : 	mass: 5.94e-01 ==> 3.40e+00 || change = 4.7184e+00 [sam.py:static_binary_density]
# 16:02:51 ERROR : Warning, significant change in number-mass!  mass: 5.94e-01 ==> 3.40e+00 || change = 4.7184e+00 [sam.py:static_binary_density]
# 16:02:51 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:51 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:51 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:51 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:51 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 6.52e-04, 3.09e-01, 2.76e+00, 4.79e+00) [sam.py:static_binary_density]
# 16:02:52 INFO : Scatter added after 0.227959 sec [sam.py:static_binary_density]
# 16:02:52 INFO : 	dens aft: (4.02e-12, 3.92e-08, 4.34e-07, 2.91e-02, 8.96e-01, 2.00e+00, 4.60e+00) [sam.py:static_binary_density]
# 16:02:52 INFO : 	mass: 7.24e-01 ==> 4.23e+00 || change = 4.8410e+00 [sam.py:static_binary_density]
# 16:02:52 ERROR : Warning, significant change in number-mass!  mass: 7.24e-01 ==> 4.23e+00 || change = 4.8410e+00 [sam.py:static_binary_density]
# 16:02:52 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:52 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:52 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:52 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:52 INFO : 	dens bef: (0.00e+00, 0.00e+00, 1.07e-184, 2.45e-03, 3.98e-01, 3.26e+00, 5.58e+00) [sam.py:static_binary_density]
# 16:02:52 INFO : Scatter added after 0.169093 sec [sam.py:static_binary_density]
# 16:02:52 INFO : 	dens aft: (1.36e-10, 4.59e-07, 9.35e-06, 3.41e-02, 1.10e+00, 2.52e+00, 5.35e+00) [sam.py:static_binary_density]
# 16:02:52 INFO : 	mass: 8.71e-01 ==> 5.14e+00 || change = 4.8949e+00 [sam.py:static_binary_density]
# 16:02:52 ERROR : Warning, significant change in number-mass!  mass: 8.71e-01 ==> 5.14e+00 || change = 4.8949e+00 [sam.py:static_binary_density]
# 16:02:52 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:52 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:52 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:52 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:52 INFO : 	dens bef: (1.40e-202, 6.11e-197, 1.88e-108, 5.43e-03, 6.29e-01, 3.93e+00, 6.50e+00) [sam.py:static_binary_density]
# 16:02:52 INFO : Scatter added after 0.121824 sec [sam.py:static_binary_density]
# 16:02:52 INFO : 	dens aft: (1.16e-09, 3.34e-06, 9.91e-05, 6.66e-02, 1.43e+00, 3.30e+00, 6.23e+00) [sam.py:static_binary_density]
# 16:02:52 INFO : 	mass: 1.06e+00 ==> 6.26e+00 || change = 4.9079e+00 [sam.py:static_binary_density]
# 16:02:52 ERROR : Warning, significant change in number-mass!  mass: 1.06e+00 ==> 6.26e+00 || change = 4.9079e+00 [sam.py:static_binary_density]
# 16:02:52 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:52 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:52 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:52 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:52 INFO : 	dens bef: (8.19e-117, 3.01e-111, 5.73e-65, 8.55e-03, 8.93e-01, 6.93e+00, 1.06e+01) [sam.py:static_binary_density]
# 16:02:52 INFO : Scatter added after 0.127363 sec [sam.py:static_binary_density]
# 16:02:52 INFO : 	dens aft: (4.46e-09, 6.49e-05, 1.54e-03, 1.28e-01, 2.20e+00, 4.70e+00, 7.81e+00) [sam.py:static_binary_density]
# 16:02:52 INFO : 	mass: 1.41e+00 ==> 8.74e+00 || change = 5.2069e+00 [sam.py:static_binary_density]
# 16:02:52 ERROR : Warning, significant change in number-mass!  mass: 1.41e+00 ==> 8.74e+00 || change = 5.2069e+00 [sam.py:static_binary_density]
# 16:02:52 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:52 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:52 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:52 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:52 INFO : 	dens bef: (6.62e-68, 1.27e-62, 3.83e-40, 9.95e-03, 1.72e+00, 8.11e+00, 3.95e+01) [sam.py:static_binary_density]
# 16:02:52 INFO : Scatter added after 0.106517 sec [sam.py:static_binary_density]
# 16:02:52 INFO : 	dens aft: (1.10e-08, 9.19e-05, 5.26e-03, 2.79e-01, 4.17e+00, 7.35e+00, 2.90e+01) [sam.py:static_binary_density]
# 16:02:52 INFO : 	mass: 2.09e+00 ==> 1.48e+01 || change = 6.0904e+00 [sam.py:static_binary_density]
# 16:02:52 ERROR : Warning, significant change in number-mass!  mass: 2.09e+00 ==> 1.48e+01 || change = 6.0904e+00 [sam.py:static_binary_density]
# 16:02:52 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# GW single source strain calculation is 30.0% done.
# 16:02:52 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:52 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:52 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:52 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 5.16e-04, 1.55e-01, 1.14e+00, 3.94e+00) [sam.py:static_binary_density]
# 16:02:52 INFO : Scatter added after 0.14458 sec [sam.py:static_binary_density]
# 16:02:52 INFO : 	dens aft: (1.42e-24, 3.65e-19, 3.34e-08, 2.14e-03, 3.19e-01, 1.33e+00, 3.77e+00) [sam.py:static_binary_density]
# 16:02:52 INFO : 	mass: 4.01e-01 ==> 1.75e+00 || change = 3.3618e+00 [sam.py:static_binary_density]
# 16:02:52 ERROR : Warning, significant change in number-mass!  mass: 4.01e-01 ==> 1.75e+00 || change = 3.3618e+00 [sam.py:static_binary_density]
# 16:02:52 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:53 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:53 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:53 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:53 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 6.01e-04, 1.77e-01, 1.31e+00, 4.58e+00) [sam.py:static_binary_density]
# 16:02:53 INFO : Scatter added after 0.111093 sec [sam.py:static_binary_density]
# 16:02:53 INFO : 	dens aft: (3.39e-24, 7.45e-19, 4.81e-08, 8.14e-03, 6.34e-01, 1.53e+00, 4.39e+00) [sam.py:static_binary_density]
# 16:02:53 INFO : 	mass: 5.12e-01 ==> 2.39e+00 || change = 3.6692e+00 [sam.py:static_binary_density]
# 16:02:53 ERROR : Warning, significant change in number-mass!  mass: 5.12e-01 ==> 2.39e+00 || change = 3.6692e+00 [sam.py:static_binary_density]
# 16:02:53 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:53 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:53 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:53 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:53 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 7.36e-04, 2.57e-01, 2.40e+00, 5.33e+00) [sam.py:static_binary_density]
# 16:02:53 INFO : Scatter added after 0.087152 sec [sam.py:static_binary_density]
# 16:02:53 INFO : 	dens aft: (6.33e-24, 1.20e-18, 9.12e-08, 1.79e-02, 7.51e-01, 1.75e+00, 5.12e+00) [sam.py:static_binary_density]
# 16:02:53 INFO : 	mass: 6.61e-01 ==> 3.41e+00 || change = 4.1582e+00 [sam.py:static_binary_density]
# 16:02:53 ERROR : Warning, significant change in number-mass!  mass: 6.61e-01 ==> 3.41e+00 || change = 4.1582e+00 [sam.py:static_binary_density]
# 16:02:53 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:53 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:53 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:53 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:53 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 8.42e-04, 3.47e-01, 3.30e+00, 6.21e+00) [sam.py:static_binary_density]
# 16:02:53 INFO : Scatter added after 0.18296 sec [sam.py:static_binary_density]
# 16:02:53 INFO : 	dens aft: (6.58e-19, 1.27e-14, 1.51e-07, 2.95e-02, 8.94e-01, 2.36e+00, 5.95e+00) [sam.py:static_binary_density]
# 16:02:53 INFO : 	mass: 8.40e-01 ==> 4.61e+00 || change = 4.4908e+00 [sam.py:static_binary_density]
# 16:02:53 ERROR : Warning, significant change in number-mass!  mass: 8.40e-01 ==> 4.61e+00 || change = 4.4908e+00 [sam.py:static_binary_density]
# 16:02:53 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:53 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:53 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:53 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:53 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 9.64e-04, 4.39e-01, 4.05e+00, 7.23e+00) [sam.py:static_binary_density]
# 16:02:53 INFO : Scatter added after 0.213092 sec [sam.py:static_binary_density]
# 16:02:53 INFO : 	dens aft: (1.82e-14, 2.71e-10, 2.15e-07, 3.92e-02, 1.22e+00, 2.95e+00, 6.93e+00) [sam.py:static_binary_density]
# 16:02:53 INFO : 	mass: 1.04e+00 ==> 5.97e+00 || change = 4.7184e+00 [sam.py:static_binary_density]
# 16:02:53 ERROR : Warning, significant change in number-mass!  mass: 1.04e+00 ==> 5.97e+00 || change = 4.7184e+00 [sam.py:static_binary_density]
# 16:02:53 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:53 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:53 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:53 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:53 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 1.15e-03, 5.42e-01, 4.85e+00, 8.42e+00) [sam.py:static_binary_density]
# 16:02:53 INFO : Scatter added after 0.163316 sec [sam.py:static_binary_density]
# 16:02:53 INFO : 	dens aft: (7.06e-12, 6.87e-08, 7.62e-07, 5.11e-02, 1.57e+00, 3.52e+00, 8.07e+00) [sam.py:static_binary_density]
# 16:02:53 INFO : 	mass: 1.27e+00 ==> 7.42e+00 || change = 4.8410e+00 [sam.py:static_binary_density]
# 16:02:53 ERROR : Warning, significant change in number-mass!  mass: 1.27e+00 ==> 7.42e+00 || change = 4.8410e+00 [sam.py:static_binary_density]
# 16:02:53 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:54 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:54 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:54 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:54 INFO : 	dens bef: (0.00e+00, 0.00e+00, 1.89e-184, 4.30e-03, 6.99e-01, 5.73e+00, 9.80e+00) [sam.py:static_binary_density]
# 16:02:54 INFO : Scatter added after 0.174401 sec [sam.py:static_binary_density]
# 16:02:54 INFO : 	dens aft: (2.40e-10, 8.05e-07, 1.64e-05, 5.98e-02, 1.93e+00, 4.42e+00, 9.39e+00) [sam.py:static_binary_density]
# 16:02:54 INFO : 	mass: 1.53e+00 ==> 9.02e+00 || change = 4.8949e+00 [sam.py:static_binary_density]
# 16:02:54 ERROR : Warning, significant change in number-mass!  mass: 1.53e+00 ==> 9.02e+00 || change = 4.8949e+00 [sam.py:static_binary_density]
# 16:02:54 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:54 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:54 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:54 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:54 INFO : 	dens bef: (2.47e-202, 1.07e-196, 3.30e-108, 9.53e-03, 1.10e+00, 6.90e+00, 1.14e+01) [sam.py:static_binary_density]
# 16:02:54 INFO : Scatter added after 0.127244 sec [sam.py:static_binary_density]
# 16:02:54 INFO : 	dens aft: (2.03e-09, 5.87e-06, 1.74e-04, 1.17e-01, 2.51e+00, 5.79e+00, 1.09e+01) [sam.py:static_binary_density]
# 16:02:54 INFO : 	mass: 1.86e+00 ==> 1.10e+01 || change = 4.9079e+00 [sam.py:static_binary_density]
# 16:02:54 ERROR : Warning, significant change in number-mass!  mass: 1.86e+00 ==> 1.10e+01 || change = 4.9079e+00 [sam.py:static_binary_density]
# 16:02:54 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:54 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:54 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:54 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:54 INFO : 	dens bef: (1.44e-116, 5.28e-111, 1.01e-64, 1.50e-02, 1.57e+00, 1.22e+01, 1.86e+01) [sam.py:static_binary_density]
# 16:02:54 INFO : Scatter added after 0.1023 sec [sam.py:static_binary_density]
# 16:02:54 INFO : 	dens aft: (7.83e-09, 1.14e-04, 2.71e-03, 2.25e-01, 3.87e+00, 8.25e+00, 1.37e+01) [sam.py:static_binary_density]
# 16:02:54 INFO : 	mass: 2.47e+00 ==> 1.53e+01 || change = 5.2069e+00 [sam.py:static_binary_density]
# 16:02:54 ERROR : Warning, significant change in number-mass!  mass: 2.47e+00 ==> 1.53e+01 || change = 5.2069e+00 [sam.py:static_binary_density]
# 16:02:54 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:54 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:54 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:54 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:54 INFO : 	dens bef: (1.16e-67, 2.23e-62, 6.72e-40, 1.75e-02, 3.03e+00, 1.42e+01, 6.93e+01) [sam.py:static_binary_density]
# 16:02:54 INFO : Scatter added after 0.159666 sec [sam.py:static_binary_density]
# 16:02:54 INFO : 	dens aft: (1.92e-08, 1.61e-04, 9.23e-03, 4.90e-01, 7.32e+00, 1.29e+01, 5.09e+01) [sam.py:static_binary_density]
# 16:02:54 INFO : 	mass: 3.67e+00 ==> 2.60e+01 || change = 6.0904e+00 [sam.py:static_binary_density]
# 16:02:54 ERROR : Warning, significant change in number-mass!  mass: 3.67e+00 ==> 2.60e+01 || change = 6.0904e+00 [sam.py:static_binary_density]
# 16:02:54 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# GW single source strain calculation is 40.0% done.
# 16:02:54 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:54 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:54 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:54 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 9.06e-04, 2.72e-01, 2.00e+00, 6.91e+00) [sam.py:static_binary_density]
# 16:02:54 INFO : Scatter added after 0.078291 sec [sam.py:static_binary_density]
# 16:02:54 INFO : 	dens aft: (2.50e-24, 6.40e-19, 5.86e-08, 3.76e-03, 5.60e-01, 2.33e+00, 6.63e+00) [sam.py:static_binary_density]
# 16:02:54 INFO : 	mass: 7.04e-01 ==> 3.07e+00 || change = 3.3618e+00 [sam.py:static_binary_density]
# 16:02:54 ERROR : Warning, significant change in number-mass!  mass: 7.04e-01 ==> 3.07e+00 || change = 3.3618e+00 [sam.py:static_binary_density]
# 16:02:54 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:54 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:54 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:54 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:54 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 1.05e-03, 3.11e-01, 2.29e+00, 8.04e+00) [sam.py:static_binary_density]
# 16:02:55 INFO : Scatter added after 0.09841 sec [sam.py:static_binary_density]
# 16:02:55 INFO : 	dens aft: (5.94e-24, 1.31e-18, 8.44e-08, 1.43e-02, 1.11e+00, 2.68e+00, 7.71e+00) [sam.py:static_binary_density]
# 16:02:55 INFO : 	mass: 8.99e-01 ==> 4.20e+00 || change = 3.6692e+00 [sam.py:static_binary_density]
# 16:02:55 ERROR : Warning, significant change in number-mass!  mass: 8.99e-01 ==> 4.20e+00 || change = 3.6692e+00 [sam.py:static_binary_density]
# 16:02:55 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:55 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:55 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:55 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:55 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 1.29e-03, 4.51e-01, 4.22e+00, 9.37e+00) [sam.py:static_binary_density]
# 16:02:55 INFO : Scatter added after 0.126989 sec [sam.py:static_binary_density]
# 16:02:55 INFO : 	dens aft: (1.11e-23, 2.10e-18, 1.60e-07, 3.14e-02, 1.32e+00, 3.08e+00, 8.98e+00) [sam.py:static_binary_density]
# 16:02:55 INFO : 	mass: 1.16e+00 ==> 5.99e+00 || change = 4.1582e+00 [sam.py:static_binary_density]
# 16:02:55 ERROR : Warning, significant change in number-mass!  mass: 1.16e+00 ==> 5.99e+00 || change = 4.1582e+00 [sam.py:static_binary_density]
# 16:02:55 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:55 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:55 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:55 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:55 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 1.48e-03, 6.10e-01, 5.80e+00, 1.09e+01) [sam.py:static_binary_density]
# 16:02:55 INFO : Scatter added after 0.166778 sec [sam.py:static_binary_density]
# 16:02:55 INFO : 	dens aft: (1.15e-18, 2.22e-14, 2.65e-07, 5.18e-02, 1.57e+00, 4.15e+00, 1.05e+01) [sam.py:static_binary_density]
# 16:02:55 INFO : 	mass: 1.48e+00 ==> 8.10e+00 || change = 4.4908e+00 [sam.py:static_binary_density]
# 16:02:55 ERROR : Warning, significant change in number-mass!  mass: 1.48e+00 ==> 8.10e+00 || change = 4.4908e+00 [sam.py:static_binary_density]
# 16:02:55 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:55 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:55 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:55 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:55 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 1.69e-03, 7.71e-01, 7.11e+00, 1.27e+01) [sam.py:static_binary_density]
# 16:02:55 INFO : Scatter added after 0.173865 sec [sam.py:static_binary_density]
# 16:02:55 INFO : 	dens aft: (3.20e-14, 4.76e-10, 3.78e-07, 6.89e-02, 2.14e+00, 5.18e+00, 1.22e+01) [sam.py:static_binary_density]
# 16:02:55 INFO : 	mass: 1.83e+00 ==> 1.05e+01 || change = 4.7184e+00 [sam.py:static_binary_density]
# 16:02:55 ERROR : Warning, significant change in number-mass!  mass: 1.83e+00 ==> 1.05e+01 || change = 4.7184e+00 [sam.py:static_binary_density]
# 16:02:55 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:55 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:55 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:55 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:55 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 2.01e-03, 9.52e-01, 8.52e+00, 1.48e+01) [sam.py:static_binary_density]
# 16:02:55 INFO : Scatter added after 0.124183 sec [sam.py:static_binary_density]
# 16:02:55 INFO : 	dens aft: (1.24e-11, 1.21e-07, 1.34e-06, 8.96e-02, 2.76e+00, 6.18e+00, 1.42e+01) [sam.py:static_binary_density]
# 16:02:55 INFO : 	mass: 2.23e+00 ==> 1.30e+01 || change = 4.8410e+00 [sam.py:static_binary_density]
# 16:02:55 ERROR : Warning, significant change in number-mass!  mass: 2.23e+00 ==> 1.30e+01 || change = 4.8410e+00 [sam.py:static_binary_density]
# 16:02:55 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:55 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:55 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:55 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:55 INFO : 	dens bef: (0.00e+00, 0.00e+00, 3.31e-184, 7.56e-03, 1.23e+00, 1.01e+01, 1.72e+01) [sam.py:static_binary_density]
# 16:02:56 INFO : Scatter added after 0.145545 sec [sam.py:static_binary_density]
# 16:02:56 INFO : 	dens aft: (4.21e-10, 1.41e-06, 2.88e-05, 1.05e-01, 3.39e+00, 7.75e+00, 1.65e+01) [sam.py:static_binary_density]
# 16:02:56 INFO : 	mass: 2.69e+00 ==> 1.58e+01 || change = 4.8949e+00 [sam.py:static_binary_density]
# 16:02:56 ERROR : Warning, significant change in number-mass!  mass: 2.69e+00 ==> 1.58e+01 || change = 4.8949e+00 [sam.py:static_binary_density]
# 16:02:56 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:56 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:56 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:56 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:56 INFO : 	dens bef: (4.33e-202, 1.88e-196, 5.80e-108, 1.67e-02, 1.94e+00, 1.21e+01, 2.00e+01) [sam.py:static_binary_density]
# 16:02:56 INFO : Scatter added after 0.100188 sec [sam.py:static_binary_density]
# 16:02:56 INFO : 	dens aft: (3.57e-09, 1.03e-05, 3.05e-04, 2.05e-01, 4.41e+00, 1.02e+01, 1.92e+01) [sam.py:static_binary_density]
# 16:02:56 INFO : 	mass: 3.27e+00 ==> 1.93e+01 || change = 4.9079e+00 [sam.py:static_binary_density]
# 16:02:56 ERROR : Warning, significant change in number-mass!  mass: 3.27e+00 ==> 1.93e+01 || change = 4.9079e+00 [sam.py:static_binary_density]
# 16:02:56 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:56 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:56 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:56 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:56 INFO : 	dens bef: (2.52e-116, 9.27e-111, 1.77e-64, 2.64e-02, 2.75e+00, 2.14e+01, 3.27e+01) [sam.py:static_binary_density]
# 16:02:56 INFO : Scatter added after 0.071282 sec [sam.py:static_binary_density]
# 16:02:56 INFO : 	dens aft: (1.37e-08, 2.00e-04, 4.76e-03, 3.95e-01, 6.79e+00, 1.45e+01, 2.41e+01) [sam.py:static_binary_density]
# 16:02:56 INFO : 	mass: 4.34e+00 ==> 2.69e+01 || change = 5.2069e+00 [sam.py:static_binary_density]
# 16:02:56 ERROR : Warning, significant change in number-mass!  mass: 4.34e+00 ==> 2.69e+01 || change = 5.2069e+00 [sam.py:static_binary_density]
# 16:02:56 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:02:56 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:02:56 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:02:56 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:02:56 INFO : 	dens bef: (2.04e-67, 3.92e-62, 1.18e-39, 3.07e-02, 5.31e+00, 2.50e+01, 1.22e+02) [sam.py:static_binary_density]
# 16:02:56 INFO : Scatter added after 0.092882 sec [sam.py:static_binary_density]
# 16:02:56 INFO : 	dens aft: (3.38e-08, 2.83e-04, 1.62e-02, 8.60e-01, 1.29e+01, 2.27e+01, 8.93e+01) [sam.py:static_binary_density]
# 16:02:56 INFO : 	mass: 6.45e+00 ==> 4.57e+01 || change = 6.0904e+00 [sam.py:static_binary_density]
# 16:02:56 ERROR : Warning, significant change in number-mass!  mass: 6.45e+00 ==> 4.57e+01 || change = 6.0904e+00 [sam.py:static_binary_density]
# 16:02:56 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# GW single source strain calculation is 50.0% done.
# ...
# 16:03:03 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 1.40e-02, 5.80e+00, 5.51e+01, 1.04e+02) [sam.py:static_binary_density]
# 16:03:04 INFO : Scatter added after 0.219264 sec [sam.py:static_binary_density]
# 16:03:04 INFO : 	dens aft: (1.10e-17, 2.11e-13, 2.52e-06, 4.92e-01, 1.49e+01, 3.94e+01, 9.93e+01) [sam.py:static_binary_density]
# 16:03:04 INFO : 	mass: 1.40e+01 ==> 7.70e+01 || change = 4.4908e+00 [sam.py:static_binary_density]
# 16:03:04 ERROR : Warning, significant change in number-mass!  mass: 1.40e+01 ==> 7.70e+01 || change = 4.4908e+00 [sam.py:static_binary_density]
# 16:03:04 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:03:04 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:03:04 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:03:04 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:03:04 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 1.61e-02, 7.32e+00, 6.75e+01, 1.21e+02) [sam.py:static_binary_density]
# 16:03:04 INFO : Scatter added after 0.224813 sec [sam.py:static_binary_density]
# 16:03:04 INFO : 	dens aft: (3.04e-13, 4.52e-09, 3.59e-06, 6.55e-01, 2.04e+01, 4.92e+01, 1.16e+02) [sam.py:static_binary_density]
# 16:03:04 INFO : 	mass: 1.74e+01 ==> 9.95e+01 || change = 4.7184e+00 [sam.py:static_binary_density]
# 16:03:04 ERROR : Warning, significant change in number-mass!  mass: 1.74e+01 ==> 9.95e+01 || change = 4.7184e+00 [sam.py:static_binary_density]
# 16:03:04 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:03:04 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:03:04 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:03:04 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:03:04 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 1.91e-02, 9.04e+00, 8.10e+01, 1.40e+02) [sam.py:static_binary_density]
# 16:03:04 INFO : Scatter added after 0.154519 sec [sam.py:static_binary_density]
# 16:03:04 INFO : 	dens aft: (1.18e-10, 1.15e-06, 1.27e-05, 8.52e-01, 2.62e+01, 5.87e+01, 1.35e+02) [sam.py:static_binary_density]
# 16:03:04 INFO : 	mass: 2.12e+01 ==> 1.24e+02 || change = 4.8410e+00 [sam.py:static_binary_density]
# 16:03:04 ERROR : Warning, significant change in number-mass!  mass: 2.12e+01 ==> 1.24e+02 || change = 4.8410e+00 [sam.py:static_binary_density]
# 16:03:04 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:03:04 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:03:04 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:03:04 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:03:04 INFO : 	dens bef: (0.00e+00, 0.00e+00, 3.15e-183, 7.18e-02, 1.17e+01, 9.56e+01, 1.63e+02) [sam.py:static_binary_density]
# 16:03:04 INFO : Scatter added after 0.123802 sec [sam.py:static_binary_density]
# 16:03:04 INFO : 	dens aft: (4.00e-09, 1.34e-05, 2.74e-04, 9.98e-01, 3.22e+01, 7.37e+01, 1.57e+02) [sam.py:static_binary_density]
# 16:03:04 INFO : 	mass: 2.55e+01 ==> 1.50e+02 || change = 4.8949e+00 [sam.py:static_binary_density]
# 16:03:04 ERROR : Warning, significant change in number-mass!  mass: 2.55e+01 ==> 1.50e+02 || change = 4.8949e+00 [sam.py:static_binary_density]
# 16:03:04 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:03:04 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:03:04 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:03:04 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:03:04 INFO : 	dens bef: (4.11e-201, 1.79e-195, 5.51e-107, 1.59e-01, 1.84e+01, 1.15e+02, 1.90e+02) [sam.py:static_binary_density]
# 16:03:05 INFO : Scatter added after 0.185402 sec [sam.py:static_binary_density]
# 16:03:05 INFO : 	dens aft: (3.39e-08, 9.79e-05, 2.90e-03, 1.95e+00, 4.19e+01, 9.66e+01, 1.82e+02) [sam.py:static_binary_density]
# 16:03:05 INFO : 	mass: 3.10e+01 ==> 1.83e+02 || change = 4.9079e+00 [sam.py:static_binary_density]
# 16:03:05 ERROR : Warning, significant change in number-mass!  mass: 3.10e+01 ==> 1.83e+02 || change = 4.9079e+00 [sam.py:static_binary_density]
# 16:03:05 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:03:05 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:03:05 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:03:05 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:03:05 INFO : 	dens bef: (2.40e-115, 8.81e-110, 1.68e-63, 2.50e-01, 2.62e+01, 2.03e+02, 3.10e+02) [sam.py:static_binary_density]
# 16:03:05 INFO : Scatter added after 0.148968 sec [sam.py:static_binary_density]
# 16:03:05 INFO : 	dens aft: (1.31e-07, 1.90e-03, 4.52e-02, 3.75e+00, 6.45e+01, 1.38e+02, 2.29e+02) [sam.py:static_binary_density]
# 16:03:05 INFO : 	mass: 4.12e+01 ==> 2.56e+02 || change = 5.2069e+00 [sam.py:static_binary_density]
# 16:03:05 ERROR : Warning, significant change in number-mass!  mass: 4.12e+01 ==> 2.56e+02 || change = 5.2069e+00 [sam.py:static_binary_density]
# 16:03:05 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:03:05 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:03:05 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:03:05 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:03:05 INFO : 	dens bef: (1.94e-66, 3.72e-61, 1.12e-38, 2.91e-01, 5.05e+01, 2.38e+02, 1.16e+03) [sam.py:static_binary_density]
# 16:03:05 INFO : Scatter added after 0.192981 sec [sam.py:static_binary_density]
# 16:03:05 INFO : 	dens aft: (3.21e-07, 2.69e-03, 1.54e-01, 8.17e+00, 1.22e+02, 2.15e+02, 8.49e+02) [sam.py:static_binary_density]
# 16:03:05 INFO : 	mass: 6.12e+01 ==> 4.34e+02 || change = 6.0904e+00 [sam.py:static_binary_density]
# 16:03:05 ERROR : Warning, significant change in number-mass!  mass: 6.12e+01 ==> 4.34e+02 || change = 6.0904e+00 [sam.py:static_binary_density]
# 16:03:05 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# GW single source strain calculation is 90.0% done.
# 16:03:05 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:03:05 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:03:05 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:03:05 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 1.51e-02, 4.53e+00, 3.34e+01, 1.15e+02) [sam.py:static_binary_density]
# 16:03:05 INFO : Scatter added after 0.114933 sec [sam.py:static_binary_density]
# 16:03:05 INFO : 	dens aft: (4.17e-23, 1.07e-17, 9.78e-07, 6.26e-02, 9.35e+00, 3.88e+01, 1.11e+02) [sam.py:static_binary_density]
# 16:03:05 INFO : 	mass: 1.17e+01 ==> 5.12e+01 || change = 3.3618e+00 [sam.py:static_binary_density]
# 16:03:05 ERROR : Warning, significant change in number-mass!  mass: 1.17e+01 ==> 5.12e+01 || change = 3.3618e+00 [sam.py:static_binary_density]
# 16:03:05 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:03:05 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:03:05 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:03:05 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:03:05 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 1.76e-02, 5.19e+00, 3.83e+01, 1.34e+02) [sam.py:static_binary_density]
# 16:03:05 INFO : Scatter added after 0.175412 sec [sam.py:static_binary_density]
# 16:03:05 INFO : 	dens aft: (9.92e-23, 2.18e-17, 1.41e-06, 2.39e-01, 1.86e+01, 4.47e+01, 1.29e+02) [sam.py:static_binary_density]
# 16:03:05 INFO : 	mass: 1.50e+01 ==> 7.00e+01 || change = 3.6692e+00 [sam.py:static_binary_density]
# 16:03:05 ERROR : Warning, significant change in number-mass!  mass: 1.50e+01 ==> 7.00e+01 || change = 3.6692e+00 [sam.py:static_binary_density]
# 16:03:05 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:03:05 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:03:05 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:03:05 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:03:05 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 2.15e-02, 7.52e+00, 7.03e+01, 1.56e+02) [sam.py:static_binary_density]
# 16:03:06 INFO : Scatter added after 0.189751 sec [sam.py:static_binary_density]
# 16:03:06 INFO : 	dens aft: (1.86e-22, 3.50e-17, 2.67e-06, 5.24e-01, 2.20e+01, 5.14e+01, 1.50e+02) [sam.py:static_binary_density]
# 16:03:06 INFO : 	mass: 1.94e+01 ==> 9.99e+01 || change = 4.1582e+00 [sam.py:static_binary_density]
# 16:03:06 ERROR : Warning, significant change in number-mass!  mass: 1.94e+01 ==> 9.99e+01 || change = 4.1582e+00 [sam.py:static_binary_density]
# 16:03:06 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:03:06 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:03:06 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:03:06 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:03:06 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 2.47e-02, 1.02e+01, 9.68e+01, 1.82e+02) [sam.py:static_binary_density]
# 16:03:06 INFO : Scatter added after 0.214532 sec [sam.py:static_binary_density]
# 16:03:06 INFO : 	dens aft: (1.93e-17, 3.71e-13, 4.43e-06, 8.63e-01, 2.62e+01, 6.92e+01, 1.74e+02) [sam.py:static_binary_density]
# 16:03:06 INFO : 	mass: 2.46e+01 ==> 1.35e+02 || change = 4.4908e+00 [sam.py:static_binary_density]
# 16:03:06 ERROR : Warning, significant change in number-mass!  mass: 2.46e+01 ==> 1.35e+02 || change = 4.4908e+00 [sam.py:static_binary_density]
# 16:03:06 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:03:06 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:03:06 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:03:06 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:03:06 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 2.82e-02, 1.29e+01, 1.19e+02, 2.12e+02) [sam.py:static_binary_density]
# 16:03:06 INFO : Scatter added after 0.16505 sec [sam.py:static_binary_density]
# 16:03:06 INFO : 	dens aft: (5.34e-13, 7.94e-09, 6.30e-06, 1.15e+00, 3.57e+01, 8.64e+01, 2.03e+02) [sam.py:static_binary_density]
# 16:03:06 INFO : 	mass: 3.06e+01 ==> 1.75e+02 || change = 4.7184e+00 [sam.py:static_binary_density]
# 16:03:06 ERROR : Warning, significant change in number-mass!  mass: 3.06e+01 ==> 1.75e+02 || change = 4.7184e+00 [sam.py:static_binary_density]
# 16:03:06 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:03:06 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:03:06 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:03:06 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:03:06 INFO : 	dens bef: (0.00e+00, 0.00e+00, 0.00e+00, 3.35e-02, 1.59e+01, 1.42e+02, 2.46e+02) [sam.py:static_binary_density]
# 16:03:06 INFO : Scatter added after 0.152504 sec [sam.py:static_binary_density]
# 16:03:06 INFO : 	dens aft: (2.07e-10, 2.01e-06, 2.23e-05, 1.50e+00, 4.61e+01, 1.03e+02, 2.36e+02) [sam.py:static_binary_density]
# 16:03:06 INFO : 	mass: 3.72e+01 ==> 2.17e+02 || change = 4.8410e+00 [sam.py:static_binary_density]
# 16:03:06 ERROR : Warning, significant change in number-mass!  mass: 3.72e+01 ==> 2.17e+02 || change = 4.8410e+00 [sam.py:static_binary_density]
# 16:03:06 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:03:06 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:03:06 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:03:06 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:03:06 INFO : 	dens bef: (0.00e+00, 0.00e+00, 5.52e-183, 1.26e-01, 2.05e+01, 1.68e+02, 2.87e+02) [sam.py:static_binary_density]
# 16:03:07 INFO : Scatter added after 0.182695 sec [sam.py:static_binary_density]
# 16:03:07 INFO : 	dens aft: (7.01e-09, 2.36e-05, 4.81e-04, 1.75e+00, 5.66e+01, 1.29e+02, 2.75e+02) [sam.py:static_binary_density]
# 16:03:07 INFO : 	mass: 4.48e+01 ==> 2.64e+02 || change = 4.8949e+00 [sam.py:static_binary_density]
# 16:03:07 ERROR : Warning, significant change in number-mass!  mass: 4.48e+01 ==> 2.64e+02 || change = 4.8949e+00 [sam.py:static_binary_density]
# 16:03:07 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:03:07 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:03:07 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:03:07 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:03:07 INFO : 	dens bef: (7.22e-201, 3.14e-195, 9.68e-107, 2.79e-01, 3.23e+01, 2.02e+02, 3.34e+02) [sam.py:static_binary_density]
# 16:03:07 INFO : Scatter added after 0.141418 sec [sam.py:static_binary_density]
# 16:03:07 INFO : 	dens aft: (5.95e-08, 1.72e-04, 5.10e-03, 3.43e+00, 7.36e+01, 1.70e+02, 3.20e+02) [sam.py:static_binary_density]
# 16:03:07 INFO : 	mass: 5.45e+01 ==> 3.22e+02 || change = 4.9079e+00 [sam.py:static_binary_density]
# 16:03:07 ERROR : Warning, significant change in number-mass!  mass: 5.45e+01 ==> 3.22e+02 || change = 4.9079e+00 [sam.py:static_binary_density]
# 16:03:07 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:03:07 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:03:07 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:03:07 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:03:07 INFO : 	dens bef: (4.21e-115, 1.55e-109, 2.95e-63, 4.40e-01, 4.59e+01, 3.56e+02, 5.45e+02) [sam.py:static_binary_density]
# 16:03:07 INFO : Scatter added after 0.175882 sec [sam.py:static_binary_density]
# 16:03:07 INFO : 	dens aft: (2.29e-07, 3.34e-03, 7.94e-02, 6.59e+00, 1.13e+02, 2.42e+02, 4.02e+02) [sam.py:static_binary_density]
# 16:03:07 INFO : 	mass: 7.24e+01 ==> 4.49e+02 || change = 5.2069e+00 [sam.py:static_binary_density]
# 16:03:07 ERROR : Warning, significant change in number-mass!  mass: 7.24e+01 ==> 4.49e+02 || change = 5.2069e+00 [sam.py:static_binary_density]
# 16:03:07 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# 16:03:07 INFO : No galaxy pair-fraction given, using galaxy merger-rate. [sam.py:__init__]
# 16:03:07 INFO : No GMT was provided, cannot calculate Galaxy-Merger based stalling. [sam.py:static_binary_density]
# 16:03:07 INFO : Adding MMbulge scatter (4.5000e-01) [sam.py:static_binary_density]
# 16:03:07 INFO : 	dens bef: (3.40e-66, 6.53e-61, 1.97e-38, 5.12e-01, 8.86e+01, 4.17e+02, 2.03e+03) [sam.py:static_binary_density]
# 16:03:07 INFO : Scatter added after 0.175156 sec [sam.py:static_binary_density]
# 16:03:07 INFO : 	dens aft: (5.63e-07, 4.73e-03, 2.70e-01, 1.43e+01, 2.14e+02, 3.78e+02, 1.49e+03) [sam.py:static_binary_density]
# 16:03:07 INFO : 	mass: 1.08e+02 ==> 7.62e+02 || change = 6.0904e+00 [sam.py:static_binary_density]
# 16:03:07 ERROR : Warning, significant change in number-mass!  mass: 1.08e+02 ==> 7.62e+02 || change = 6.0904e+00 [sam.py:static_binary_density]
# 16:03:07 INFO : `gmt_time` not calculated in SAM.  Setting to zeros. [sam.py:gwb]
# Done
